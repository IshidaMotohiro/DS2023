# %% [markdown]
# ## What to do with Kaggle
#
#
#
# Kaggle is a globally recognized competition site for data analysis. Over the next five weeks, each of you will be tasked with tackling a specific competition on Kaggle.
#
# The competitions you'll be challenging will be designated from next week onwards, but for this week, you are to compete in the Titanic data competition and submit your results as this week's quiz by the 30th of next week.
#
# The competition for the Titanic data can be found below.
#
# First, you will participate in the competition.
#
#
# Kaggleは世界的なデータ分析のコンペサイトです。これから5週間の期間に、それぞれがKaggleの特定のコンペに挑戦してもらいます。
# 挑戦していただくコンペは、改めて来週以降に指定しますが、今回は、Tiatnic号データのコンペに挑戦し、その結果を今回の小テストとして来週30日までに提出してもらいます。
#
# Titanic号のコンペは以下にあります。
#
# まずコンペに参加します。
#
#
# ![](../images/Titanic1.png)
#
# At this point, precautions will be presented, so please read them carefully. Next, you will create a new notebook.
#
# この際、注意事項が提示されますので、よく読んでください。
# 次に、ノートブックを新規作成します。
#
#
#
# ![image.png](../images/Titanic2.png)
#
#
# There's no need to specify the name of the notebook, but while editing the code later, press the "Share" button in the upper right and change this notebook to Public. At the same time, make sure to note down the URL that appears.
#
# 特に名前を指定する必要はないですが、後で、コードの編集中に、右上の「共有」ボタンを押して、このノートブックをPublicに変更し、同時に表示されるURLをメモしておいてください。
#
# ノートブックの名前を指定する必要はないですが、後で、コードの編集中に、右上の「共有」ボタンを押して、このノートブックをPublicに変更し、同時に表示されるURLをメモしておいてください。
#
#
#
# ![](../images/Kaggle_share.png)
#
# In the future, when you are asked to submit Kaggle-related assignments, you will need to enter this URL each time.
#
# 今後、Kaggle関係の課題の提出を求める際には、このURLをその都度、入力してもらいます。

# %% [markdown]
# Please proceed with your work after watching the following official Kaggle tutorial.
#
# 以下のKaggle公式の解説を視聴してから、自分で作業を進めてください。
#
# Each one of you is required to analyze the Titanic data on Kaggle, make survival predictions, and submit those results to Kaggle.
#
# Also submit the URL of the kernel that represents your submitted results on Manaba week10exam quiz.
#
# Remember to set the Share option in the upper right of the kernel editing screen to Public. To confirm whether it's set to Public, input the URL into a private model browser and verify whether your created kernel is displayed before answering the Manaba quiz. (Please note that if it's not displayed, you will be evaluated on attendance points only.)
#
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/8yZMXCaFshs" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/GJBOMWpLpTQ" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#
#
#
# ### play list
#
# https://youtube.com/playlist?list=PLqFaTIg4myu8gbDh6oBl7XRYNBlthpDEW
#
#
# ## sample of Notebook
#
# https://infoart.ait231.tokushima-u.ac.jp/public/notebooke9b25a365d.pdf
